# %%
tt = 625102.56
maus = 1350000

per = tt / maus
print (per);
# Out:
# 0.4630389333333334

# %%
monthlyFee = 17.00
discount = .17
annual = monthlyFee * 12
AnnualWdisc = annual * discount

print(annual)
print(AnnualWdisc)
print(annual - AnnualWdisc)
# Out:
# 204.0
# 34.68
# 169.32
